# %%
import pandas as pd 
import polars as pl

# %%
df = pd.read_parquet('C:/Users/srabh/OneDrive/Documents/Jane_Street_Data_Challenge/data/datasets_symbols/symbol_15_merged.parquet')

# %%
df
# Out:
#          date_id  time_id  symbol_id    weight  feature_00  feature_01  \
# 0              1        0         15  0.615878         NaN         NaN
# 1              1        1         15  0.615878         NaN         NaN
# 2              1        2         15  0.615878         NaN         NaN
# 3              1        3         15  0.615878         NaN         NaN
# 4              1        4         15  0.615878         NaN         NaN
# ...          ...      ...        ...       ...         ...         ...
# 1367842     1698      963         15  1.686074    2.271343   -0.823997
# 1367843     1698      964         15  1.686074    2.226865   -0.416945
# 1367844     1698      965         15  1.686074    2.126026   -1.373968
# 1367845     1698      966         15  1.686074    2.384074   -0.281144
# 1367846     1698      967         15  1.686074    2.071874   -1.127766
#
#          feature_02  feature_03  feature_04  feature_05  ...  feature_78  \
# 0               NaN         NaN         NaN    0.038281  ...    2.302238
# 1               NaN         NaN         NaN   -0.017170  ...    2.816110
# 2               NaN         NaN         NaN    0.010079  ...    3.920522
# 3               NaN         NaN         NaN    0.166952  ...    3.032991
# 4               NaN         NaN         NaN   -0.016639  ...    2.536190
# ...             ...         ...         ...         ...  ...         ...
# 1367842    2.767182    2.071992    0.850945    0.500041  ...    0.428958
# 1367843    2.180948    2.033652    0.280157    0.521161  ...    0.324412
# 1367844    2.265700    2.397969    0.387026    0.916697  ...    0.283679
# 1367845    2.863753    2.661032    0.683144    0.785627  ...    0.272144
# 1367846    2.736025    2.369568    0.125078    0.729738  ...    0.321158
#
#          responder_0  responder_1  responder_2  responder_3  responder_4  \
# 0          -0.243050     1.759308     0.848355    -0.332405     0.650443
# 1           0.481271     1.734144     1.009305    -0.500640     0.666390
# 2          -0.333898     1.718995    -1.434416    -0.306390     0.478103
# 3          -0.238144     1.854594    -0.646138    -0.579186     0.730399
# 4          -0.139303     1.792003    -0.772957    -0.309870     0.650585
# ...              ...          ...          ...          ...          ...
# 1367842    -0.503615     0.238425    -0.500147    -1.249239    -1.121636
# 1367843     0.341634     0.180426    -0.684448    -1.678423    -1.292623
# 1367844    -1.238300     0.234585    -0.792002    -2.219057    -0.747421
# 1367845    -1.635513     0.240798    -1.083065    -2.478297    -0.957986
# 1367846    -1.017480     0.504421    -0.312986    -2.400821    -0.887522
#
#          responder_5  responder_6  responder_7  responder_8
# 0          -0.740239    -0.338148    -0.658097    -1.342462
# 1          -0.816962    -1.672627    -1.125723    -1.305906
# 2          -0.864398    -0.236729    -0.730844     1.480768
# 3          -0.766751    -0.311996    -1.063106     0.477493
# 4          -0.444985    -0.183749    -0.977267     0.697073
# ...              ...          ...          ...          ...
# 1367842     0.079978     0.135887     0.100543     0.716235
# 1367843    -0.237577     0.008129     0.032126     0.001715
# 1367844    -0.096113     0.045669     0.072158     0.106774
# 1367845    -0.491982     0.023855     0.033483     0.034568
# 1367846    -0.390340    -0.128865    -0.047167    -0.341617
#
# [1367847 rows x 92 columns]

# %%
df['responder_6']
# Out:
# 0         -0.338148
# 1         -1.672627
# 2         -0.236729
# 3         -0.311996
# 4         -0.183749
#              ...
# 1367842    0.135887
# 1367843    0.008129
# 1367844    0.045669
# 1367845    0.023855
# 1367846   -0.128865
# Name: responder_6, Length: 1367847, dtype: float32

# %%
# Pour créer plusieurs lags (par exemple 5 lags)
for i in range(1, 150):
    df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)

# Si vous voulez juste un lag spécifique, par exemple lag 1 :
df['responder_6_lag1'] = df['responder_6'].shift(1)
# Out:
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)
# C:\Users\srabh\AppData\Local\Temp\ipykernel_26472\2990621555.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'responder_6_lag{i}'] = df['responder_6'].shift(i)

# %%
df
# Out:
#          date_id  time_id  symbol_id    weight  feature_00  feature_01  \
# 0              1        0         15  0.615878         NaN         NaN
# 1              1        1         15  0.615878         NaN         NaN
# 2              1        2         15  0.615878         NaN         NaN
# 3              1        3         15  0.615878         NaN         NaN
# 4              1        4         15  0.615878         NaN         NaN
# ...          ...      ...        ...       ...         ...         ...
# 1367842     1698      963         15  1.686074    2.271343   -0.823997
# 1367843     1698      964         15  1.686074    2.226865   -0.416945
# 1367844     1698      965         15  1.686074    2.126026   -1.373968
# 1367845     1698      966         15  1.686074    2.384074   -0.281144
# 1367846     1698      967         15  1.686074    2.071874   -1.127766
#
#          feature_02  feature_03  feature_04  feature_05  ...  \
# 0               NaN         NaN         NaN    0.038281  ...
# 1               NaN         NaN         NaN   -0.017170  ...
# 2               NaN         NaN         NaN    0.010079  ...
# 3               NaN         NaN         NaN    0.166952  ...
# 4               NaN         NaN         NaN   -0.016639  ...
# ...             ...         ...         ...         ...  ...
# 1367842    2.767182    2.071992    0.850945    0.500041  ...
# 1367843    2.180948    2.033652    0.280157    0.521161  ...
# 1367844    2.265700    2.397969    0.387026    0.916697  ...
# 1367845    2.863753    2.661032    0.683144    0.785627  ...
# 1367846    2.736025    2.369568    0.125078    0.729738  ...
#
#          responder_6_lag140  responder_6_lag141  responder_6_lag142  \
# 0                       NaN                 NaN                 NaN
# 1                       NaN                 NaN                 NaN
# 2                       NaN                 NaN                 NaN
# 3                       NaN                 NaN                 NaN
# 4                       NaN                 NaN                 NaN
# ...                     ...                 ...                 ...
# 1367842           -1.136852           -2.056716           -1.488419
# 1367843           -0.562720           -1.136852           -2.056716
# 1367844           -1.466155           -0.562720           -1.136852
# 1367845           -0.800211           -1.466155           -0.562720
# 1367846           -1.142632           -0.800211           -1.466155
#
#          responder_6_lag143  responder_6_lag144  responder_6_lag145  \
# 0                       NaN                 NaN                 NaN
# 1                       NaN                 NaN                 NaN
# 2                       NaN                 NaN                 NaN
# 3                       NaN                 NaN                 NaN
# 4                       NaN                 NaN                 NaN
# ...                     ...                 ...                 ...
# 1367842           -1.914081           -1.312252           -2.636375
# 1367843           -1.488419           -1.914081           -1.312252
# 1367844           -2.056716           -1.488419           -1.914081
# 1367845           -1.136852           -2.056716           -1.488419
# 1367846           -0.562720           -1.136852           -2.056716
#
#          responder_6_lag146  responder_6_lag147  responder_6_lag148  \
# 0                       NaN                 NaN                 NaN
# 1                       NaN                 NaN                 NaN
# 2                       NaN                 NaN                 NaN
# 3                       NaN                 NaN                 NaN
# 4                       NaN                 NaN                 NaN
# ...                     ...                 ...                 ...
# 1367842           -1.789878           -1.935262           -1.846104
# 1367843           -2.636375           -1.789878           -1.935262
# 1367844           -1.312252           -2.636375           -1.789878
# 1367845           -1.914081           -1.312252           -2.636375
# 1367846           -1.488419           -1.914081           -1.312252
#
#          responder_6_lag149
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 1367842           -1.543228
# 1367843           -1.846104
# 1367844           -1.935262
# 1367845           -1.789878
# 1367846           -2.636375
#
# [1367847 rows x 241 columns]

# %%
selected_columns = ['responder_6'] + [col for col in df.columns if col.startswith('responder_6_lag')]
df_selected = df[selected_columns]

# %%
df_selected
# Out:
#          responder_6  responder_6_lag1  responder_6_lag2  responder_6_lag3  \
# 0          -0.338148               NaN               NaN               NaN
# 1          -1.672627         -0.338148               NaN               NaN
# 2          -0.236729         -1.672627         -0.338148               NaN
# 3          -0.311996         -0.236729         -1.672627         -0.338148
# 4          -0.183749         -0.311996         -0.236729         -1.672627
# ...              ...               ...               ...               ...
# 1367842     0.135887          0.076382         -0.077019         -0.077877
# 1367843     0.008129          0.135887          0.076382         -0.077019
# 1367844     0.045669          0.008129          0.135887          0.076382
# 1367845     0.023855          0.045669          0.008129          0.135887
# 1367846    -0.128865          0.023855          0.045669          0.008129
#
#          responder_6_lag4  responder_6_lag5  responder_6_lag6  \
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4               -0.338148               NaN               NaN
# ...                   ...               ...               ...
# 1367842         -0.119116         -0.118608          0.069649
# 1367843         -0.077877         -0.119116         -0.118608
# 1367844         -0.077019         -0.077877         -0.119116
# 1367845          0.076382         -0.077019         -0.077877
# 1367846          0.135887          0.076382         -0.077019
#
#          responder_6_lag7  responder_6_lag8  responder_6_lag9  ...  \
# 0                     NaN               NaN               NaN  ...
# 1                     NaN               NaN               NaN  ...
# 2                     NaN               NaN               NaN  ...
# 3                     NaN               NaN               NaN  ...
# 4                     NaN               NaN               NaN  ...
# ...                   ...               ...               ...  ...
# 1367842          0.179148          0.105134          0.271826  ...
# 1367843          0.069649          0.179148          0.105134  ...
# 1367844         -0.118608          0.069649          0.179148  ...
# 1367845         -0.119116         -0.118608          0.069649  ...
# 1367846         -0.077877         -0.119116         -0.118608  ...
#
#          responder_6_lag140  responder_6_lag141  responder_6_lag142  \
# 0                       NaN                 NaN                 NaN
# 1                       NaN                 NaN                 NaN
# 2                       NaN                 NaN                 NaN
# 3                       NaN                 NaN                 NaN
# 4                       NaN                 NaN                 NaN
# ...                     ...                 ...                 ...
# 1367842           -1.136852           -2.056716           -1.488419
# 1367843           -0.562720           -1.136852           -2.056716
# 1367844           -1.466155           -0.562720           -1.136852
# 1367845           -0.800211           -1.466155           -0.562720
# 1367846           -1.142632           -0.800211           -1.466155
#
#          responder_6_lag143  responder_6_lag144  responder_6_lag145  \
# 0                       NaN                 NaN                 NaN
# 1                       NaN                 NaN                 NaN
# 2                       NaN                 NaN                 NaN
# 3                       NaN                 NaN                 NaN
# 4                       NaN                 NaN                 NaN
# ...                     ...                 ...                 ...
# 1367842           -1.914081           -1.312252           -2.636375
# 1367843           -1.488419           -1.914081           -1.312252
# 1367844           -2.056716           -1.488419           -1.914081
# 1367845           -1.136852           -2.056716           -1.488419
# 1367846           -0.562720           -1.136852           -2.056716
#
#          responder_6_lag146  responder_6_lag147  responder_6_lag148  \
# 0                       NaN                 NaN                 NaN
# 1                       NaN                 NaN                 NaN
# 2                       NaN                 NaN                 NaN
# 3                       NaN                 NaN                 NaN
# 4                       NaN                 NaN                 NaN
# ...                     ...                 ...                 ...
# 1367842           -1.789878           -1.935262           -1.846104
# 1367843           -2.636375           -1.789878           -1.935262
# 1367844           -1.312252           -2.636375           -1.789878
# 1367845           -1.914081           -1.312252           -2.636375
# 1367846           -1.488419           -1.914081           -1.312252
#
#          responder_6_lag149
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 1367842           -1.543228
# 1367843           -1.846104
# 1367844           -1.935262
# 1367845           -1.789878
# 1367846           -2.636375
#
# [1367847 rows x 150 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Création du plot
plt.figure(figsize=(10, 8))

# Créer le scatter plot avec une densité de points (kde)
sns.scatterplot(data=df_selected, 
                x='responder_6_lag1',  # Vous pouvez changer le lag ici (lag1, lag2, etc.)
                y='responder_6',
                alpha=0.1)  # Pour rendre les points plus transparents

# Calculer la corrélation
correlation = df_selected['responder_6'].corr(df_selected['responder_6_lag1'])

# Ajouter le titre et les labels
plt.title('Responder vs Its Lag')
plt.xlabel('lag 6')
plt.ylabel('responder 6')

# Ajouter la corrélation comme texte sur le plot
plt.text(0.7, 0.1, f'Correlation = {correlation:.2f}', 
         transform=plt.gca().transAxes, 
         fontsize=12)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Calculate correlation matrix
correlation_matrix = df_selected.corr()

# Create the plot
plt.figure(figsize=(12, 8))

# Create heatmap
sns.heatmap(correlation_matrix, 
            annot=True,  # Show numbers
            cmap='RdGy',  # Color scheme
            vmin=-1, vmax=1,  # Set limits for correlation values
            center=0,  # Center the colormap at 0
            fmt='.2f',  # Show 2 decimal places
            square=True)  # Make cells square

# Set title
plt.title('Correlation Matrix of Responder 6 and its Lags', pad=20)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)
plt.yticks(rotation=0)

# Adjust layout to prevent label cutoff
plt.tight_layout()

# Show plot
plt.show()
